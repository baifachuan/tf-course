# %% [markdown]
# # Feed dict

# %% [markdown]
# # 构建图

# %%
import tensorflow as tf

# 创建一个常量 op, 产生一个 1x2 矩阵. 这个 op 被作为一个节点
# 加到默认图中.
#
# 构造器的返回值代表该常量 op 的返回值.
matrix1 = tf.constant([[3., 3.]])

# 创建另外一个常量 op, 产生一个 2x1 矩阵.
matrix2 = tf.constant([[2.],[2.]])

# 创建一个矩阵乘法 matmul op , 把 'matrix1' 和 'matrix2' 作为输入.
# 返回值 'product' 代表矩阵乘法的结果.
product = tf.matmul(matrix1, matrix2)

# %% [markdown]
# # 在一个会话中启动图

# %%
# 启动默认图.
sess = tf.Session()

# 调用 sess 的 'run()' 方法来执行矩阵乘法 op, 传入 'product' 作为该方法的参数. 
# 上面提到, 'product' 代表了矩阵乘法 op 的输出, 传入它是向方法表明, 我们希望取回
# 矩阵乘法 op 的输出.
#
# 整个执行过程是自动化的, 会话负责传递 op 所需的全部输入. op 通常是并发执行的.
# 
# 函数调用 'run(product)' 触发了图中三个 op (两个常量 op 和一个矩阵乘法 op) 的执行.
#
# 返回值 'result' 是一个 numpy `ndarray` 对象.
result = sess.run(product)
print(result)
# ==> [[ 12.]]

# 任务完成, 关闭会话.
sess.close()
# Out:
# [[ 12.]]

# %% [markdown]
# # 交互式使用

# %%
# 进入一个交互式 TensorFlow 会话.
import tensorflow as tf
sess = tf.InteractiveSession()

x = tf.Variable([1.0, 2.0])
a = tf.constant([3.0, 3.0])

# 使用初始化器 initializer op 的 run() 方法初始化 'x' 
x.initializer.run()

# 增加一个减法 sub op, 从 'x' 减去 'a'. 运行减法 op, 输出结果 
sub = tf.subtract(x, a)
print(sub.eval())
# ==> [-2. -1.]
# Out:
# [-2. -1.]

# %% [markdown]
# # 变量

# %%
# 创建一个变量, 初始化为标量 0.
state = tf.Variable(0, name="counter")

# 创建一个 op, 其作用是使 state 增加 1

one = tf.constant(1)
new_value = tf.add(state, one)
update = tf.assign(state, new_value)

# 启动图后, 变量必须先经过`初始化` (init) op 初始化,
# 首先必须增加一个`初始化` op 到图中.
init_op = tf.global_variables_initializer()

# 启动图, 运行 op
with tf.Session() as sess:
  # 运行 'init' op
  sess.run(init_op)
  # 打印 'state' 的初始值
  print(sess.run(state))
  # 运行 op, 更新 'state', 并打印 'state'
  for _ in range(3):
    sess.run(update)
    print(sess.run(state))

# 输出:

# 0
# 1
# 2
# 3
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# FailedPreconditionError: Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-47-418b53a20a24> in <module>()
#      15 with tf.Session() as sess:
#      16   # 运行 'init' op
# ---> 17   sess.run(init_op)
#      18   # 打印 'state' 的初始值
#      19   print(sess.run(state))
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# FailedPreconditionError: Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]
#
# Caused by op 'Variable_5/read', defined at:
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 405, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/ioloop.py", line 883, in start
#     handler_func(fd_obj, events)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 260, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 212, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 370, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 175, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2902, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3006, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3066, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-36-a8528ac445fa>", line 1, in <module>
#     x = tf.Variable(10)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 197, in __init__
#     expected_shape=expected_shape)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 315, in _init_from_args
#     self._snapshot = array_ops.identity(self._variable, name="read")
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1490, in identity
#     result = _op_def_lib.apply_op("Identity", input=input, name=name)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# FailedPreconditionError (see above for traceback): Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]

# %%
x = tf.Variable(10)
#y = tf.Variable(x.intialized_value() * 2)

# Create a variable with a random value.
#weights = tf.Variable(tf.random_normal([784, 200], stddev=0.35), name="weights")
# Create another variable with the same value as 'weights'.
#w2 = tf.Variable(weights.initialized_value(), name="w2")
# Create another variable with twice the value of 'weights'
#w_twice = tf.Variable(weights.initialized_value() * 2.0, name="w_twice")

init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    print(sess.run(x))
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# FailedPreconditionError: Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-42-5d32399ecbab> in <module>()
#      11 init = tf.global_variables_initializer()
#      12 with tf.Session() as sess:
# ---> 13     sess.run(init)
#      14     print(sess.run(x))
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# FailedPreconditionError: Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]
#
# Caused by op 'Variable_5/read', defined at:
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/runpy.py", line 170, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/traitlets/config/application.py", line 592, in launch_instance
#     app.start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 405, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/ioloop.py", line 883, in start
#     handler_func(fd_obj, events)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 260, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 212, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 370, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 175, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2902, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3006, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3066, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-36-a8528ac445fa>", line 1, in <module>
#     x = tf.Variable(10)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 197, in __init__
#     expected_shape=expected_shape)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/variables.py", line 315, in _init_from_args
#     self._snapshot = array_ops.identity(self._variable, name="read")
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1490, in identity
#     result = _op_def_lib.apply_op("Identity", input=input, name=name)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2327, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/twcn/.pyenv/versions/3.5.1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1226, in __init__
#     self._traceback = _extract_stack()
#
# FailedPreconditionError (see above for traceback): Attempting to use uninitialized value Variable_5
# 	 [[Node: Variable_5/read = Identity[T=DT_INT32, _class=["loc:@Variable_5"], _device="/job:localhost/replica:0/task:0/cpu:0"](Variable_5)]]

# %% [markdown]
# # Fetch获取

# %%
input1 = tf.constant(3.0)
input2 = tf.constant(2.0)
input3 = tf.constant(5.0)
intermed = tf.add(input2, input3)
mul = tf.multiply(input1, intermed)

with tf.Session() as sess:
  result = sess.run([mul, intermed])
  print(result)

# 输出:
# [array([ 21.], dtype=float32), array([ 7.], dtype=float32)]
# Out:
# [21.0, 7.0]

# %% [markdown]
# # Feed

# %%
input1 = tf.placeholder(tf.float32)
input2 = tf.placeholder(tf.float32)
output = tf.multiply(input1, input2)

with tf.Session() as sess:
  print(sess.run([output], feed_dict={input1:[7.], input2:[2.]}))

# 输出:
# [array([ 14.], dtype=float32)]
# Out:
# [array([ 14.], dtype=float32)]

# %% [markdown]
# # 随机数

# %%
# Create a tensor of shape [2, 3] consisting of random normal values, with mean
# -1 and standard deviation 4.
norm = tf.random_normal([2, 3], mean=-1, stddev=4)

# Shuffle the first dimension of a tensor
c = tf.constant([[1, 2], [3, 4], [5, 6]])
shuff = tf.random_shuffle(c)

# Each time we run these ops, different results are generated
sess = tf.Session()
print(sess.run(norm))
print(sess.run(norm))

# Set an op-level seed to generate repeatable sequences across sessions.
norm = tf.random_normal([2, 3], seed=1234)
sess = tf.Session()
print(sess.run(norm))
print(sess.run(norm))
sess = tf.Session()
print(sess.run(norm))
print(sess.run(norm))
# Out:
# [[-0.93629909 -0.67032504 -1.17526686]
#  [-5.01312304 -3.7200675  -2.18491602]]
# [[ 1.41843033  0.02026236 -5.59527397]
#  [ 3.18753672 -1.72027469 -1.18558073]]
# [[ 0.51340485 -0.25581399  0.65199131]
#  [ 1.39236379  0.37256798  0.20336303]]
# [[ 0.96462417  0.34291974  0.24251089]
#  [ 1.05785966  1.65749764  0.82108968]]
# [[ 0.51340485 -0.25581399  0.65199131]
#  [ 1.39236379  0.37256798  0.20336303]]
# [[ 0.96462417  0.34291974  0.24251089]
#  [ 1.05785966  1.65749764  0.82108968]]

# %%
var = tf.Variable(tf.random_uniform([2, 3]), name="var")
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)
print(sess.run(var))
# Out:
# [[ 0.86286163  0.95342338  0.27628613]
#  [ 0.90594792  0.95073986  0.38398623]]

# %%
import tensorflow as tf

# Example 1: feed_dict with placeholder
# create a placeholder of type float 32-bit, value is a vector of 3 elements
a = tf.placeholder(tf.float32, shape=[3])

# create a constant of type float 32-bit, value is a vector of 3 elements
b = tf.constant([5, 5, 5], tf.float32)

# use the placeholder as you would a constant
c = a + b  # short for tf.add(a, b)

with tf.Session() as sess:
	#print(sess.run(c)) # error because a doesn’t have any value
	# feed [1, 2, 3] to placeholder a via the dict {a: [1, 2, 3]}
	# fetch value of c
	print(sess.run(c, {a: [1, 2, 3]})) # >> [6. 7. 8.]


# Example 2: feed_dict with variables
a = tf.add(2, 5)
b = tf.multiply(a, 3)

with tf.Session() as sess:
	# define a dictionary that says to replace the value of 'a' with 15
	replace_dict = {a: 15}
	# Run the session, passing in 'replace_dict' as the value to 'feed_dict'
	sess.run(b, feed_dict=replace_dict) # >> 45
# Out:
# [ 6.  7.  8.]

# %% [markdown]
# # 正常加载

# %%
import tensorflow as tf

# normal loading
x = tf.Variable(10, name='x')
y = tf.Variable(20, name='y')
z = tf.add(x, y)

with tf.Session() as sess:
	sess.run(tf.global_variables_initializer())
	writer = tf.summary.FileWriter('./my_graph/l2', sess.graph)
	for _ in range(10):
		sess.run(z)
	print(tf.get_default_graph().as_graph_def())
	writer.close()
# Out:
# node {
#   name: "Placeholder"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add"
#   op: "Add"
#   input: "Placeholder"
#   input: "Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Placeholder_1"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add_1"
#   op: "Add"
#   input: "Placeholder_1"
#   input: "Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Placeholder_2"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add_2"
#   op: "Add"
#   input: "Placeholder_2"
#   input: "Const_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Add/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Add/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "Add"
#   op: "Add"
#   input: "Add/x"
#   input: "Add/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Mul/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 3
#       }
#     }
#   }
# }
# node {
#   name: "Mul"
#   op: "Mul"
#   input: "Add"
#   input: "Mul/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "x/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x/Assign"
#   op: "Assign"
#   input: "x"
#   input: "x/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x/read"
#   op: "Identity"
#   input: "x"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x"
#       }
#     }
#   }
# }
# node {
#   name: "y/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y/Assign"
#   op: "Assign"
#   input: "y"
#   input: "y/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y/read"
#   op: "Identity"
#   input: "y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y"
#       }
#     }
#   }
# }
# node {
#   name: "Add_1"
#   op: "Add"
#   input: "x/read"
#   input: "y/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
# }
# node {
#   name: "x_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_1/Assign"
#   op: "Assign"
#   input: "x_1"
#   input: "x_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_1/read"
#   op: "Identity"
#   input: "x_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_1"
#       }
#     }
#   }
# }
# node {
#   name: "y_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_1/Assign"
#   op: "Assign"
#   input: "y_1"
#   input: "y_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_1/read"
#   op: "Identity"
#   input: "y_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_1"
#       }
#     }
#   }
# }
# node {
#   name: "init_1"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
# }
# node {
#   name: "Add_2"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_3"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_4"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_5"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_6"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_7"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_8"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_9"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_10"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_11"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Variable/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "Variable"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable/Assign"
#   op: "Assign"
#   input: "Variable"
#   input: "Variable/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable/read"
#   op: "Identity"
#   input: "Variable"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
# }
# node {
#   name: "Assign/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 100
#       }
#     }
#   }
# }
# node {
#   name: "Assign"
#   op: "Assign"
#   input: "Variable"
#   input: "Assign/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "my_var/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "my_var"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "my_var/Assign"
#   op: "Assign"
#   input: "my_var"
#   input: "my_var/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "my_var/read"
#   op: "Identity"
#   input: "my_var"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
# }
# node {
#   name: "mul/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "mul"
#   op: "Mul"
#   input: "mul/x"
#   input: "my_var/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Assign_1"
#   op: "Assign"
#   input: "my_var"
#   input: "mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "init_2"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
# }
# node {
#   name: "Variable_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "Variable_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable_1/Assign"
#   op: "Assign"
#   input: "Variable_1"
#   input: "Variable_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable_1/read"
#   op: "Identity"
#   input: "Variable_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd"
#   op: "AssignAdd"
#   input: "Variable_1"
#   input: "AssignAdd/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignSub/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "AssignSub"
#   op: "AssignSub"
#   input: "Variable_1"
#   input: "AssignSub/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignAdd_1/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 100
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd_1"
#   op: "AssignAdd"
#   input: "Variable_1"
#   input: "AssignAdd_1/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignSub_1/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 50
#       }
#     }
#   }
# }
# node {
#   name: "AssignSub_1"
#   op: "AssignSub"
#   input: "Variable_1"
#   input: "AssignSub_1/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "x_2/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_2"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_2/Assign"
#   op: "Assign"
#   input: "x_2"
#   input: "x_2/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_2"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_2/read"
#   op: "Identity"
#   input: "x_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_2"
#       }
#     }
#   }
# }
# node {
#   name: "y_2/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_2"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_2/Assign"
#   op: "Assign"
#   input: "y_2"
#   input: "y_2/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_2"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_2/read"
#   op: "Identity"
#   input: "y_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_2"
#       }
#     }
#   }
# }
# node {
#   name: "Add_12"
#   op: "Add"
#   input: "x_2/read"
#   input: "y_2/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_3"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
# }
# node {
#   name: "x_3/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_3"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_3/Assign"
#   op: "Assign"
#   input: "x_3"
#   input: "x_3/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_3"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_3/read"
#   op: "Identity"
#   input: "x_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_3"
#       }
#     }
#   }
# }
# node {
#   name: "y_3/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_3"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_3/Assign"
#   op: "Assign"
#   input: "y_3"
#   input: "y_3/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_3"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_3/read"
#   op: "Identity"
#   input: "y_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_3"
#       }
#     }
#   }
# }
# node {
#   name: "init_4"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
# }
# node {
#   name: "Add_13"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_14"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_15"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_16"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_17"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_18"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_19"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_20"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_21"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_22"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "x_4/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_4"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_4/Assign"
#   op: "Assign"
#   input: "x_4"
#   input: "x_4/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_4"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_4/read"
#   op: "Identity"
#   input: "x_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_4"
#       }
#     }
#   }
# }
# node {
#   name: "y_4/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_4"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_4/Assign"
#   op: "Assign"
#   input: "y_4"
#   input: "y_4/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_4"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_4/read"
#   op: "Identity"
#   input: "y_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_4"
#       }
#     }
#   }
# }
# node {
#   name: "Add_23"
#   op: "Add"
#   input: "x_4/read"
#   input: "y_4/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_5"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
#   input: "^x_4/Assign"
#   input: "^y_4/Assign"
# }
# node {
#   name: "x_5/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_5"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_5/Assign"
#   op: "Assign"
#   input: "x_5"
#   input: "x_5/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_5"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_5/read"
#   op: "Identity"
#   input: "x_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_5"
#       }
#     }
#   }
# }
# node {
#   name: "y_5/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_5"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_5/Assign"
#   op: "Assign"
#   input: "y_5"
#   input: "y_5/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_5"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_5/read"
#   op: "Identity"
#   input: "y_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_5"
#       }
#     }
#   }
# }
# node {
#   name: "Add_24"
#   op: "Add"
#   input: "x_5/read"
#   input: "y_5/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_6"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
#   input: "^x_4/Assign"
#   input: "^y_4/Assign"
#   input: "^x_5/Assign"
#   input: "^y_5/Assign"
# }
# versions {
#   producer: 21
# }

# %% [markdown]
# # 延迟加载

# %%
# lazy loading
x = tf.Variable(10, name='x')
y = tf.Variable(20, name='y')

with tf.Session() as sess:
	sess.run(tf.global_variables_initializer())
	writer = tf.summary.FileWriter('./my_graph/l3', sess.graph)
	for _ in range(10):
		sess.run(tf.add(x, y))
	print(tf.get_default_graph().as_graph_def())
	writer.close()
# Out:
# node {
#   name: "Placeholder"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add"
#   op: "Add"
#   input: "Placeholder"
#   input: "Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Placeholder_1"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add_1"
#   op: "Add"
#   input: "Placeholder_1"
#   input: "Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Placeholder_2"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\000\000\240@\000\000\240@\000\000\240@"
#       }
#     }
#   }
# }
# node {
#   name: "add_2"
#   op: "Add"
#   input: "Placeholder_2"
#   input: "Const_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Add/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "Add/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 5
#       }
#     }
#   }
# }
# node {
#   name: "Add"
#   op: "Add"
#   input: "Add/x"
#   input: "Add/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Mul/y"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 3
#       }
#     }
#   }
# }
# node {
#   name: "Mul"
#   op: "Mul"
#   input: "Add"
#   input: "Mul/y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "x/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x/Assign"
#   op: "Assign"
#   input: "x"
#   input: "x/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x/read"
#   op: "Identity"
#   input: "x"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x"
#       }
#     }
#   }
# }
# node {
#   name: "y/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y/Assign"
#   op: "Assign"
#   input: "y"
#   input: "y/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y/read"
#   op: "Identity"
#   input: "y"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y"
#       }
#     }
#   }
# }
# node {
#   name: "Add_1"
#   op: "Add"
#   input: "x/read"
#   input: "y/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
# }
# node {
#   name: "x_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_1/Assign"
#   op: "Assign"
#   input: "x_1"
#   input: "x_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_1/read"
#   op: "Identity"
#   input: "x_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_1"
#       }
#     }
#   }
# }
# node {
#   name: "y_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_1/Assign"
#   op: "Assign"
#   input: "y_1"
#   input: "y_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_1/read"
#   op: "Identity"
#   input: "y_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_1"
#       }
#     }
#   }
# }
# node {
#   name: "init_1"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
# }
# node {
#   name: "Add_2"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_3"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_4"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_5"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_6"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_7"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_8"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_9"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_10"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_11"
#   op: "Add"
#   input: "x_1/read"
#   input: "y_1/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Variable/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "Variable"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable/Assign"
#   op: "Assign"
#   input: "Variable"
#   input: "Variable/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable/read"
#   op: "Identity"
#   input: "Variable"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
# }
# node {
#   name: "Assign/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 100
#       }
#     }
#   }
# }
# node {
#   name: "Assign"
#   op: "Assign"
#   input: "Variable"
#   input: "Assign/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "my_var/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "my_var"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "my_var/Assign"
#   op: "Assign"
#   input: "my_var"
#   input: "my_var/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "my_var/read"
#   op: "Identity"
#   input: "my_var"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
# }
# node {
#   name: "mul/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "mul"
#   op: "Mul"
#   input: "mul/x"
#   input: "my_var/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Assign_1"
#   op: "Assign"
#   input: "my_var"
#   input: "mul"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@my_var"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "init_2"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
# }
# node {
#   name: "Variable_1/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "Variable_1"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "Variable_1/Assign"
#   op: "Assign"
#   input: "Variable_1"
#   input: "Variable_1/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Variable_1/read"
#   op: "Identity"
#   input: "Variable_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd"
#   op: "AssignAdd"
#   input: "Variable_1"
#   input: "AssignAdd/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignSub/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "AssignSub"
#   op: "AssignSub"
#   input: "Variable_1"
#   input: "AssignSub/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignAdd_1/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 100
#       }
#     }
#   }
# }
# node {
#   name: "AssignAdd_1"
#   op: "AssignAdd"
#   input: "Variable_1"
#   input: "AssignAdd_1/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "AssignSub_1/value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 50
#       }
#     }
#   }
# }
# node {
#   name: "AssignSub_1"
#   op: "AssignSub"
#   input: "Variable_1"
#   input: "AssignSub_1/value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@Variable_1"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "x_2/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_2"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_2/Assign"
#   op: "Assign"
#   input: "x_2"
#   input: "x_2/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_2"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_2/read"
#   op: "Identity"
#   input: "x_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_2"
#       }
#     }
#   }
# }
# node {
#   name: "y_2/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_2"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_2/Assign"
#   op: "Assign"
#   input: "y_2"
#   input: "y_2/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_2"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_2/read"
#   op: "Identity"
#   input: "y_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_2"
#       }
#     }
#   }
# }
# node {
#   name: "Add_12"
#   op: "Add"
#   input: "x_2/read"
#   input: "y_2/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_3"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
# }
# node {
#   name: "x_3/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_3"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_3/Assign"
#   op: "Assign"
#   input: "x_3"
#   input: "x_3/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_3"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_3/read"
#   op: "Identity"
#   input: "x_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_3"
#       }
#     }
#   }
# }
# node {
#   name: "y_3/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_3"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_3/Assign"
#   op: "Assign"
#   input: "y_3"
#   input: "y_3/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_3"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_3/read"
#   op: "Identity"
#   input: "y_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_3"
#       }
#     }
#   }
# }
# node {
#   name: "init_4"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
# }
# node {
#   name: "Add_13"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_14"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_15"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_16"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_17"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_18"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_19"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_20"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_21"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_22"
#   op: "Add"
#   input: "x_3/read"
#   input: "y_3/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "x_4/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_4"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_4/Assign"
#   op: "Assign"
#   input: "x_4"
#   input: "x_4/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_4"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_4/read"
#   op: "Identity"
#   input: "x_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_4"
#       }
#     }
#   }
# }
# node {
#   name: "y_4/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_4"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_4/Assign"
#   op: "Assign"
#   input: "y_4"
#   input: "y_4/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_4"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_4/read"
#   op: "Identity"
#   input: "y_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_4"
#       }
#     }
#   }
# }
# node {
#   name: "Add_23"
#   op: "Add"
#   input: "x_4/read"
#   input: "y_4/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_5"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
#   input: "^x_4/Assign"
#   input: "^y_4/Assign"
# }
# node {
#   name: "x_5/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_5"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_5/Assign"
#   op: "Assign"
#   input: "x_5"
#   input: "x_5/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_5"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_5/read"
#   op: "Identity"
#   input: "x_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_5"
#       }
#     }
#   }
# }
# node {
#   name: "y_5/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_5"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_5/Assign"
#   op: "Assign"
#   input: "y_5"
#   input: "y_5/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_5"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_5/read"
#   op: "Identity"
#   input: "y_5"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_5"
#       }
#     }
#   }
# }
# node {
#   name: "Add_24"
#   op: "Add"
#   input: "x_5/read"
#   input: "y_5/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "init_6"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
#   input: "^x_4/Assign"
#   input: "^y_4/Assign"
#   input: "^x_5/Assign"
#   input: "^y_5/Assign"
# }
# node {
#   name: "x_6/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 10
#       }
#     }
#   }
# }
# node {
#   name: "x_6"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "x_6/Assign"
#   op: "Assign"
#   input: "x_6"
#   input: "x_6/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_6"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "x_6/read"
#   op: "Identity"
#   input: "x_6"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@x_6"
#       }
#     }
#   }
# }
# node {
#   name: "y_6/initial_value"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 20
#       }
#     }
#   }
# }
# node {
#   name: "y_6"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "y_6/Assign"
#   op: "Assign"
#   input: "y_6"
#   input: "y_6/initial_value"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_6"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "y_6/read"
#   op: "Identity"
#   input: "y_6"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@y_6"
#       }
#     }
#   }
# }
# node {
#   name: "init_7"
#   op: "NoOp"
#   input: "^x/Assign"
#   input: "^y/Assign"
#   input: "^x_1/Assign"
#   input: "^y_1/Assign"
#   input: "^Variable/Assign"
#   input: "^my_var/Assign"
#   input: "^Variable_1/Assign"
#   input: "^x_2/Assign"
#   input: "^y_2/Assign"
#   input: "^x_3/Assign"
#   input: "^y_3/Assign"
#   input: "^x_4/Assign"
#   input: "^y_4/Assign"
#   input: "^x_5/Assign"
#   input: "^y_5/Assign"
#   input: "^x_6/Assign"
#   input: "^y_6/Assign"
# }
# node {
#   name: "Add_25"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_26"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_27"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_28"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_29"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_30"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_31"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_32"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_33"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "Add_34"
#   op: "Add"
#   input: "x_6/read"
#   input: "y_6/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# versions {
#   producer: 21
# }

# %% [markdown]
# # 变量

# %%
import tensorflow as tf

# Example 1: how to run assign op
W = tf.Variable(10)
assign_op = W.assign(100)

with tf.Session() as sess:
	sess.run(W.initializer)
	print(W.eval()) # >> 10
	print(sess.run(assign_op)) # >> 100

# Example 2: tricky example
# create a variable whose original value is 2
my_var = tf.Variable(2, name="my_var") 

# assign 2 * my_var to my_var and run the op my_var_times_two
my_var_times_two = my_var.assign(2 * my_var)

with tf.Session() as sess:
	sess.run(tf.global_variables_initializer())
	print(sess.run(my_var_times_two)) # >> 4
	print(sess.run(my_var_times_two)) # >> 8
	print(sess.run(my_var_times_two)) # >> 16

# Example 3: each session maintains its own copy of variables
W = tf.Variable(10)
sess1 = tf.Session()
sess2 = tf.Session()

# You have to initialize W at each session
sess1.run(W.initializer)
sess2.run(W.initializer)

print(sess1.run(W.assign_add(10))) # >> 20
print(sess2.run(W.assign_sub(2))) # >> 8

print(sess1.run(W.assign_add(100))) # >> 120
print(sess2.run(W.assign_sub(50))) # >> -42

sess1.close()
sess2.close()
# Out:
# 10
# 100
# 4
# 8
# 16
# 20
# 8
# 120
# -42
